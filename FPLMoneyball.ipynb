# %%
# %pip install fplstat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: fplstat in ./.local/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: numpy>=2.4.1 in ./.local/lib/python3.12/site-packages (from fplstat) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from fplstat) (2.3.3)
# Requirement already satisfied: pydantic>=2.12.5 in ./.local/lib/python3.12/site-packages (from fplstat) (2.13.4)
# Requirement already satisfied: requests>=2.32.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from fplstat) (2.32.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.3.3->fplstat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.3.3->fplstat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.3.3->fplstat) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=2.12.5->fplstat) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.local/lib/python3.12/site-packages (from pydantic>=2.12.5->fplstat) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=2.12.5->fplstat) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=2.12.5->fplstat) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.3.3->fplstat) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.32.5->fplstat) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.32.5->fplstat) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.32.5->fplstat) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.32.5->fplstat) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import numpy as np
from collections import defaultdict
import aiohttp
import asyncio
from fpl import FPL

bootstrap = requests.get(
    "https://fantasy.premierleague.com/api/bootstrap-static/"
).json()

fixtures = requests.get(
    "https://fantasy.premierleague.com/api/fixtures/"
).json()

players = bootstrap["elements"]
teams = bootstrap["teams"]

print(f"{len(players)} players loaded")
print(f"{len(fixtures)} fixtures loaded")
# Out:
# 652 players loaded
# 380 fixtures loaded

# %%
players_df = pd.DataFrame(players)

players_df = players_df[
    [
        "id",
        "web_name",
        "team",
        "element_type",
        "now_cost",
        "total_points",
        "form",
        "minutes"
    ]
].copy()

players_df.columns = [
    "id",
    "name",
    "team",
    "position",
    "price",
    "points",
    "form",
    "minutes"
]

players_df["price"] = players_df["price"] / 10
players_df["form"] = players_df["form"].astype(float)

players_df.head()
# Out:
#    id          name  team  position  price  points  form  minutes
# 0   1          Raya     1         1    6.0      12   4.0      180
# 1   2  Arrizabalaga     1         1    4.9       0   0.0        0
# 2   3       Meslier     1         1    4.9       0   0.0        0
# 3   4       Gabriel     1         2    8.0      13   4.3      180
# 4   5      J.Timber     1         2    6.5       0   0.0        0

# %%
fixture_weights = {
    1: 1.30,
    2: 1.15,
    3: 1.00,
    4: 0.90,
    5: 0.75
}

# %%
from collections import defaultdict

LOOKAHEAD = 5

team_fixtures = defaultdict(list)

for fixture in fixtures:

    if fixture["finished"]:
        continue

    home_team = fixture["team_h"]
    away_team = fixture["team_a"]

    home_diff = fixture["team_h_difficulty"]
    away_diff = fixture["team_a_difficulty"]

    team_fixtures[home_team].append(home_diff)
    team_fixtures[away_team].append(away_diff)

# %%
fixture_scores = {}

for team, diffs in team_fixtures.items():

    next_five = diffs[:LOOKAHEAD]

    score = sum(
        fixture_weights[d]
        for d in next_five
    )

    fixture_scores[team] = score

# %%
if len(fixture_scores) == 0:
    players_df["fixture_score"] = 1.0
else:
    players_df["fixture_score"] = (
        players_df["team"]
        .map(fixture_scores)
        .fillna(1.0)
    )

# %%
#LOAD HISTORICAL TRAINING DATA


import pandas as pd

print("Loading historical FPL data...")

# Historical gameweek-by-gameweek data
history_url = (
    "https://raw.githubusercontent.com/"
    "vaastav/Fantasy-Premier-League/"
    "master/data/2024-25/gws/merged_gw.csv"
)

history_df = pd.read_csv(history_url)

print(f"Loaded {len(history_df)} historical player-gameweeks.")

print("\nDataset shape:")
print(history_df.shape)

print("\nColumns:")
print(history_df.columns.tolist())

print("\nFirst five rows:")
display(history_df.head())
# Out:
# Loading historical FPL data...
# Loaded 27605 historical player-gameweeks.
#
# Dataset shape:
# (27605, 49)
#
# Columns:
# ['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes', 'mng_clean_sheets', 'mng_draw', 'mng_goals_scored', 'mng_loss', 'mng_underdog_draw', 'mng_underdog_win', 'mng_win', 'modified', 'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score', 'threat', 'total_points', 'transfers_balance', 'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards', 'GW']
#
# First five rows:
#                                name position            team   xP  assists  \
# 0                        Alex Scott      MID     Bournemouth  1.6        0
# 1  Carlos Miguel dos Santos Pereira       GK   Nott'm Forest  2.2        0
# 2                 Tomiyasu Takehiro      DEF         Arsenal  0.0        0
# 3                   Malcolm Ebiowei      MID  Crystal Palace  0.0        0
# 4                 Ben Brereton Díaz      MID     Southampton  1.0        0
#
#    bonus  bps  clean_sheets  creativity  element  ...  team_h_score  threat  \
# 0      0   11             0        12.8       77  ...             1     0.0
# 1      0    0             0         0.0      427  ...             1     0.0
# 2      0    0             0         0.0       22  ...             2     0.0
# 3      0    0             0         0.0      197  ...             2     0.0
# 4      0   -2             0        14.0      584  ...             1    16.0
#
#    total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0             2                  0             0              0     50
# 1             0                  0             0              0     45
# 2             0                  0             0              0     50
# 3             0                  0             0              0     45
# 4             1                  0             0              0     55
#
#    was_home  yellow_cards GW
# 0     False             0  1
# 1      True             0  1
# 2      True             0  1
# 3     False             0  1
# 4     False             1  1
#
# [5 rows x 49 columns]

# %%
#FEATURE ENGINEERING


from sklearn.preprocessing import LabelEncoder

print("Preparing machine learning dataset...")

# Selects only features available
# in both history_df and players_df


ml_df = history_df[
    [
        "minutes",
        "value",
        "position",
        "team",
        "total_points"
    ]
].copy()


# Converts numeric columns


ml_df["minutes"] = pd.to_numeric(
    ml_df["minutes"],
    errors="coerce"
)

ml_df["value"] = pd.to_numeric(
    ml_df["value"],
    errors="coerce"
)


# Encodes categorical variables

position_encoder = LabelEncoder()
team_encoder = LabelEncoder()

ml_df["position"] = position_encoder.fit_transform(
    ml_df["position"]
)

ml_df["team"] = team_encoder.fit_transform(
    ml_df["team"]
)


# Removes incomplete rows


ml_df = ml_df.dropna()

print(f"Training rows: {len(ml_df)}")

# Features and target


feature_columns = [
    "minutes",
    "value",
    "position",
    "team"
]

X = ml_df[feature_columns]

y = ml_df["total_points"]

print("\nFeatures ready!")
print(f"{X.shape[1]} features")
print(f"{X.shape[0]} training examples")

print("\nFeatures used:")
for feature in feature_columns:
    print("-", feature)
# Out:
# Preparing machine learning dataset...
# Training rows: 27605
#
# Features ready!
# 4 features
# 27605 training examples
#
# Features used:
# - minutes
# - value
# - position
# - team

# %%
#Trains a Random Forest model

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

print("Training Random Forest model...")


# Train / Test Split


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)


# Build Model


rf_model = RandomForestRegressor(
    n_estimators=500,
    max_depth=10,
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)

# Train


rf_model.fit(X_train, y_train)

print("Training complete!")


# Evaluate


predictions = rf_model.predict(X_test)

mae = mean_absolute_error(
    y_test,
    predictions
)

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        predictions
    )
)

r2 = r2_score(
    y_test,
    predictions
)

print("\nMODEL PERFORMANCE")
print(f"Mean Absolute Error : {mae:.2f}")
print(f"Root Mean Squared Error : {rmse:.2f}")
print(f"R² Score : {r2:.3f}")


# Feature Importance


importance = pd.DataFrame({
    "Feature": feature_columns,
    "Importance": rf_model.feature_importances_
})

importance = importance.sort_values(
    "Importance",
    ascending=False
)

print("\n FEATURE IMPORTANCE")
display(importance)

print("\nModel is ready for live FPL predictions.")
# Out:
# Training Random Forest model...
# Training complete!
#
# MODEL PERFORMANCE
# Mean Absolute Error : 0.78
# Root Mean Squared Error : 1.80
# R² Score : 0.458
#
#  FEATURE IMPORTANCE
#     Feature  Importance
# 0   minutes    0.717515
# 1     value    0.173945
# 2  position    0.056917
# 3      team    0.051623
# Model is ready for live FPL predictions.

# %%
#ml setup inspection


import pandas as pd

print("HISTORY DATA INFO")

# 1. Columns in historical dataset
print("\n[1] history_df columns:")
print(history_df.columns.tolist())

# 2. First row preview (helps identify feature names + structure)
print("\n[2] history_df sample row:")
print(history_df.head(1).T)

# 3. Check for common ML-relevant columns
print("\n[3] Key column presence check:")

key_columns = [
    "total_points",
    "minutes",
    "bps",
    "influence",
    "creativity",
    "threat",
    "ict_index",
    "opponent_team",
    "was_home",
    "team_h",
    "team_a",
    "expected_goals",
    "expected_assists"
]

for col in key_columns:
    print(f"{col}: {'YES' if col in history_df.columns else 'NO'}")

print("\nDONE")
# Out:
# HISTORY DATA INFO
#
# [1] history_df columns:
# ['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes', 'mng_clean_sheets', 'mng_draw', 'mng_goals_scored', 'mng_loss', 'mng_underdog_draw', 'mng_underdog_win', 'mng_win', 'modified', 'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score', 'threat', 'total_points', 'transfers_balance', 'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards', 'GW']
#
# [2] history_df sample row:
#                                                0
# name                                  Alex Scott
# position                                     MID
# team                                 Bournemouth
# xP                                           1.6
# assists                                        0
# bonus                                          0
# bps                                           11
# clean_sheets                                   0
# creativity                                  12.8
# element                                       77
# expected_assists                            0.01
# expected_goal_involvements                  0.01
# expected_goals                               0.0
# expected_goals_conceded                     1.02
# fixture                                        6
# goals_conceded                                 1
# goals_scored                                   0
# ict_index                                    3.6
# influence                                   22.8
# kickoff_time                2024-08-17T14:00:00Z
# minutes                                       62
# mng_clean_sheets                             NaN
# mng_draw                                     NaN
# mng_goals_scored                             NaN
# mng_loss                                     NaN
# mng_underdog_draw                            NaN
# mng_underdog_win                             NaN
# mng_win                                      NaN
# modified                                   False
# opponent_team                                 16
# own_goals                                      0
# penalties_missed                               0
# penalties_saved                                0
# red_cards                                      0
# round                                          1
# saves                                          0
# selected                                    4339
# starts                                         1
# team_a_score                                   1
# team_h_score                                   1
# threat                                       0.0
# total_points                                   2
# transfers_balance                              0
# transfers_in                                   0
# transfers_out                                  0
# value                                         50
# was_home                                   False
# yellow_cards                                   0
# GW                                             1
#
# [3] Key column presence check:
# total_points: YES
# minutes: YES
# bps: YES
# influence: YES
# creativity: YES
# threat: YES
# ict_index: YES
# opponent_team: YES
# was_home: YES
# team_h: NO
# team_a: NO
# expected_goals: YES
# expected_assists: YES
#
# DONE

# %%
#predicting player quality

print("Predicting player quality...")

from sklearn.preprocessing import LabelEncoder

# Encode live data the same way as training


live_df = players_df.copy()

# Position encoding
position_encoder = LabelEncoder()

live_df["position"] = position_encoder.fit_transform(
    live_df["position"]
)

# Team encoding
team_encoder = LabelEncoder()

live_df["team"] = team_encoder.fit_transform(
    live_df["team"]
)


# Build prediction dataframe


prediction_features = pd.DataFrame()

prediction_features["minutes"] = live_df["minutes"]

# Historical value column is price × 10
prediction_features["value"] = live_df["price"] * 10

prediction_features["position"] = live_df["position"]

prediction_features["team"] = live_df["team"]

prediction_features = prediction_features.fillna(0)


# Predict base player quality


players_df["ml_prediction"] = rf_model.predict(
    prediction_features[feature_columns]
)


# Scale using recent form


players_df["ml_prediction"] = (
    players_df["ml_prediction"]
    *
    (
        0.5
        +
        players_df["form"] /
        (players_df["form"].max() + 0.01)
    )
)


# Apply next-five fixture adjustment


players_df["projected_points"] = (
    players_df["ml_prediction"]
    *
    players_df["fixture_score"]
)

# Value metric


players_df["value_score"] = (
    players_df["projected_points"]
    /
    players_df["price"]
)

print("\nML predictions complete.")

print("\nTop 10 projected players:")

display(
    players_df[
        [
            "name",
            "price",
            "form",
            "fixture_score",
            "ml_prediction",
            "projected_points",
            "value_score"
        ]
    ]
    .sort_values(
        "projected_points",
        ascending=False
    )
    .head(10)
)
# Out:
# Predicting player quality...
#
# ML predictions complete.
#
# Top 10 projected players:
#             name  price  form  fixture_score  ml_prediction  projected_points  \
# 507  B.Fernandes   12.0   8.3           4.90      12.549432         61.492217
# 450         Isak    9.0   7.7           5.20       7.537545         39.195234
# 473       Cherki    7.8   8.3           5.25       6.992220         36.709154
# 438        Gakpo    7.1   9.3           5.20       6.906403         35.913293
# 567  Gibbs-White    7.9   6.0           4.95       6.423815         31.797882
# 76         Scott    6.0   8.0           4.95       6.328788         31.327502
# 179   João Pedro    7.7   6.7           4.90       6.381010         31.266947
# 465     Gvardiol    5.6   7.3           5.25       5.703387         29.942782
# 75     Tavernier    6.0   7.0           4.95       5.828687         28.851998
# 482      Haaland   15.5   8.0           5.25       5.460466         28.667445
#
#      value_score
# 507     5.124351
# 450     4.355026
# 473     4.706302
# 438     5.058210
# 567     4.025048
# 76      5.221250
# 179     4.060642
# 465     5.346925
# 75      4.808666
# 482     1.849513

# %%
print(fixtures[:2])
# Out:
# [{'code': 2645195, 'event': 1, 'finished': True, 'finished_provisional': True, 'id': 1, 'kickoff_time': '2026-08-21T19:00:00Z', 'minutes': 90, 'provisional_start_time': False, 'started': True, 'team_a': 7, 'team_a_score': 0, 'team_h': 1, 'team_h_score': 3, 'stats': [{'identifier': 'goals_scored', 'a': [], 'h': [{'value': 1, 'element': 12}, {'value': 1, 'element': 15}, {'value': 1, 'element': 26}]}, {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 8}, {'value': 1, 'element': 10}, {'value': 1, 'element': 557}]}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 575}], 'h': [{'value': 1, 'element': 4}]}, {'identifier': 'red_cards', 'a': [], 'h': []}, {'identifier': 'saves', 'a': [{'value': 2, 'element': 110}], 'h': [{'value': 1, 'element': 1}]}, {'identifier': 'bonus', 'a': [], 'h': [{'value': 3, 'element': 15}, {'value': 2, 'element': 10}, {'value': 1, 'element': 12}]}, {'identifier': 'bps', 'a': [{'value': 14, 'element': 184}, {'value': 11, 'element': 173}, {'value': 11, 'element': 190}, {'value': 9, 'element': 194}, {'value': 8, 'element': 104}, {'value': 8, 'element': 188}, {'value': 7, 'element': 195}, {'value': 4, 'element': 492}, {'value': 3, 'element': 183}, {'value': 3, 'element': 584}, {'value': 2, 'element': 575}, {'value': 1, 'element': 182}, {'value': -4, 'element': 176}, {'value': -8, 'element': 175}], 'h': [{'value': 41, 'element': 15}, {'value': 37, 'element': 10}, {'value': 36, 'element': 12}, {'value': 34, 'element': 26}, {'value': 31, 'element': 8}, {'value': 30, 'element': 557}, {'value': 27, 'element': 11}, {'value': 24, 'element': 1}, {'value': 21, 'element': 4}, {'value': 15, 'element': 7}, {'value': 10, 'element': 13}, {'value': 8, 'element': 16}, {'value': 5, 'element': 17}, {'value': 4, 'element': 14}, {'value': 3, 'element': 9}, {'value': 3, 'element': 19}]}, {'identifier': 'defensive_contribution', 'a': [{'value': 10, 'element': 173}, {'value': 9, 'element': 104}, {'value': 9, 'element': 182}, {'value': 8, 'element': 190}, {'value': 7, 'element': 175}, {'value': 7, 'element': 184}, {'value': 6, 'element': 176}, {'value': 6, 'element': 194}, {'value': 5, 'element': 183}, {'value': 3, 'element': 195}, {'value': 3, 'element': 575}, {'value': 1, 'element': 188}, {'value': 1, 'element': 492}, {'value': 1, 'element': 584}], 'h': [{'value': 8, 'element': 15}, {'value': 7, 'element': 7}, {'value': 7, 'element': 12}, {'value': 6, 'element': 11}, {'value': 6, 'element': 13}, {'value': 6, 'element': 557}, {'value': 5, 'element': 8}, {'value': 5, 'element': 10}, {'value': 4, 'element': 4}, {'value': 3, 'element': 19}, {'value': 2, 'element': 14}, {'value': 2, 'element': 16}, {'value': 2, 'element': 17}, {'value': 2, 'element': 26}]}], 'team_h_difficulty': 2, 'team_a_difficulty': 5, 'pulse_id': 0}, {'code': 2645198, 'event': 1, 'finished': True, 'finished_provisional': True, 'id': 4, 'kickoff_time': '2026-08-22T11:30:00Z', 'minutes': 90, 'provisional_start_time': False, 'started': True, 'team_a': 16, 'team_a_score': 0, 'team_h': 11, 'team_h_score': 2, 'stats': [{'identifier': 'goals_scored', 'a': [], 'h': [{'value': 1, 'element': 279}, {'value': 1, 'element': 586}]}, {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 290}, {'value': 1, 'element': 295}]}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 415}], 'h': [{'value': 1, 'element': 287}, {'value': 1, 'element': 289}]}, {'identifier': 'red_cards', 'a': [], 'h': []}, {'identifier': 'saves', 'a': [{'value': 2, 'element': 412}], 'h': [{'value': 5, 'element': 572}]}, {'identifier': 'bonus', 'a': [], 'h': [{'value': 3, 'element': 572}, {'value': 2, 'element': 279}, {'value': 1, 'element': 586}]}, {'identifier' ...

# %%
players_df["value_score"] = (
    players_df["projected_points"]
    / players_df["price"]
)

# %%
# Enter FPL Team ID and fetch squad


team_id = int(input("Enter your FPL Team ID: "))

current_gw = next(
    event["id"]
    for event in bootstrap["events"]
    if event["is_current"]
)

print(current_gw)

picks_url = (
    f"https://fantasy.premierleague.com/api/"
    f"entry/{team_id}/event/{current_gw}/picks/"
)

picks_data = requests.get(picks_url).json()

user_squad = []

for pick in picks_data["picks"]:
    player = players_df[players_df["id"] == pick["element"]].iloc[0]

    user_squad.append({
        "id": pick["element"],
        "selling_price": player["price"]
    })

user_squad_df = pd.DataFrame(user_squad)

user_squad_ids = user_squad_df["id"].tolist()

bank = (
    picks_data["entry_history"]["bank"] / 10
)

print(f"Bank: £{bank}m")
# Out:
# Enter your FPL Team ID:  1046527
# 3
# Bank: £0.0m

# %%
squad_df = (
    players_df[
        players_df["id"].isin(user_squad_ids)
    ]
    .merge(
        user_squad_df,
        on="id",
        how="left"
    )
)

# %%
squad_df["projected_points"] = squad_df["projected_points"].replace(0,np.nan)

# %%
squad_df["sell_score"] = (
    squad_df["price"]
    / (squad_df["projected_points"] + 0.001)
)

# %%
print(players_df["form"].describe())
# Out:
# count    652.000000
# mean       1.276534
# std        1.824038
# min       -0.700000
# 25%        0.000000
# 50%        0.300000
# 75%        2.000000
# max        9.300000
# Name: form, dtype: float64

# %%
print(squad_df[["name", "projected_points", "sell_score"]].head())
# Out:
#         name  projected_points  sell_score
# 0       Cash          7.884346    0.570679
# 1  N.Jackson          9.448188    0.687890
# 2     Kayode         15.378022    0.299109
# 3     Thomas          9.513143    0.420427
# 4     Slater          8.023873    0.560757

# %%
player_out = squad_df.loc[
    squad_df["sell_score"].idxmax()
]

player_out
# Out:
# id                       497
# name                Dubravka
# team                      19
# position                   1
# price                    4.0
# points                     0
# form                     0.0
# minutes                    0
# fixture_score           5.05
# ml_prediction       1.057084
# projected_points    5.338272
# value_score         1.334568
# selling_price            4.0
# sell_score          0.749166
# Name: 14, dtype: object

# %%
max_price = (
    player_out["selling_price"]
    + bank
)

print(
    f"Sell {player_out['name']} "
    f"for up to £{max_price:.1f}m"
)
# Out:
# Sell Dubravka for up to £4.0m

# %%
owned_players = set(
    squad_df["id"]
)

# %%
candidates = players_df[
    (players_df["position"] == player_out["position"])
    &
    (players_df["price"] <= max_price)
    &
    (~players_df["id"].isin(owned_players))
].copy()

# %%
candidates["gain"] = (
    candidates["projected_points"]
    -
    player_out["projected_points"]
)

# %%
candidates["value_score"] = (
    candidates["projected_points"]
    /
    candidates["price"]
)

# %%
candidates["budget_usage"] = (
    candidates["price"]
    /
    max_price
)

# %%
candidates["recommendation_score"] = (
    (
        0.5 * candidates["value_score"]
        +
        0.3 * candidates["fixture_score"]
        +
        0.2 * candidates["budget_usage"]
    )
    *
    np.maximum(
        candidates["gain"],
        0
    )
)

# %%
recommendations = candidates.sort_values(
    "recommendation_score",
    ascending=False
)

recommendations[
    [
        "name",
        "price",
        "projected_points",
        "fixture_score",
        "gain",
        "recommendation_score"
    ]
].head(10) #end of transfer recommendation code
# Out:
#           name  price  projected_points  fixture_score      gain  \
# 251   Matthews    4.0          8.393385           5.15  3.055113
# 358     Button    4.0          8.447243           4.80  3.108971
# 357     Palmer    4.0          8.447243           4.80  3.108971
# 120     Steele    4.0          8.006495           5.20  2.668223
# 285    McNally    4.0          7.748932           5.10  2.410660
# 284    Lecomte    4.0          7.748932           5.10  2.410660
# 417     Cairns    4.0          7.658367           4.80  2.320095
# 418   Zetterer    4.0          7.658367           4.80  2.320095
# 624  Patterson    4.0          7.612717           4.80  2.274446
# 424      Pecsi    4.0          7.117037           5.20  1.778765
#
#      recommendation_score
# 251              8.536514
# 358              8.381492
# 357              8.381492
# 120              7.366461
# 285              6.505447
# 284              6.505447
# 417              6.025974
# 418              6.025974
# 624              5.894430
# 424              4.713069

# %%
# best triple captain feature
remaining_fixtures = [
    f for f in fixtures
    if not f["finished"]
]

triple_scores = []

for _, player in players_df.iterrows():

    gw_scores = defaultdict(float)

    for fixture in remaining_fixtures:

        gw = fixture["event"]

        if gw is None:
            continue

        if fixture["team_h"] == player["team"]:
            difficulty = fixture["team_h_difficulty"]

        elif fixture["team_a"] == player["team"]:
            difficulty = fixture["team_a_difficulty"]

        else:
            continue

        fixture_projection = (
            player["projected_points"] *
            fixture_weights[difficulty]
)

        gw_scores[gw] += fixture_projection

    if len(gw_scores) == 0:
        continue

    first_half = {
        gw: score
        for gw, score in gw_scores.items()
        if gw <= 19
    }

    second_half = {
        gw: score
        for gw, score in gw_scores.items()
        if gw >= 20
    }

    if first_half:

        best_gw = max(first_half, key=first_half.get)

        triple_scores.append({
            "id": player["id"],
            "name": player["name"],
            "half": 1,
            "gw": best_gw,
            "expected_points": first_half[best_gw]
        })

    if second_half:

        best_gw = max(second_half, key=second_half.get)

        triple_scores.append({
            "id": player["id"],
            "name": player["name"],
            "half": 2,
            "gw": best_gw,
            "expected_points": second_half[best_gw]
        })

triple_df = pd.DataFrame(triple_scores)

# %%
for half in [1, 2]:

    best = (
        triple_df[triple_df["half"] == half]
        .sort_values("expected_points", ascending=False)
        .iloc[0]
    )

    print(f"\nBest triple captain in game: (Half {half})")
    print(f"Player: {best['name']}")
    print(f"Gameweek: {best['gw']}")
    print(f"Expected Points: {best['expected_points']:.2f}")
# Out:
# Best triple captain in game: (Half 1)
# Player: B.Fernandes
# Gameweek: 14
# Expected Points: 70.72
#
# Best triple captain in game: (Half 2)
# Player: B.Fernandes
# Gameweek: 20
# Expected Points: 70.72

# %%
user_tc = triple_df[
    triple_df["id"].isin(user_squad_ids)
]

for half in [1, 2]:

    best = (
        user_tc[user_tc["half"] == half]
        .sort_values("expected_points", ascending=False)
        .iloc[0]
    )

    print(f"\nYour best triple captain (Half {half})")
    print(f"Player: {best['name']}")
    print(f"Gameweek: {best['gw']}")
    print(f"Expected Points: {best['expected_points']:.2f}")
# Out:
# Your best triple captain (Half 1)
# Player: Isak
# Gameweek: 3
# Expected Points: 45.07
#
# Your best triple captain (Half 2)
# Player: Isak
# Gameweek: 25
# Expected Points: 45.07

# %%
#best free hit week feature

from collections import defaultdict

#finds the teams weakest gw

remaining_fixtures = [
    f for f in fixtures
    if not f["finished"] and f["event"] is not None
]

# key = gameweek
# value = projected team score
team_gw_scores = defaultdict(float)

for _, player in squad_df.iterrows():

    player_team = player["team"]

    for fixture in remaining_fixtures:

        if fixture["team_h"] == player_team:

            difficulty = fixture["team_h_difficulty"]

        elif fixture["team_a"] == player_team:

            difficulty = fixture["team_a_difficulty"]

        else:
            continue

        gw = fixture["event"]

        # Projected points for THIS fixture only
        fixture_projection = (
            player["projected_points"]
            *
            fixture_weights[difficulty]
        )

        # Automatically adds both fixtures if
        # the team has a double gameweek
        team_gw_scores[gw] += fixture_projection



# Split season into halves

first_half_scores = {
    gw: score
    for gw, score in team_gw_scores.items()
    if gw <= 19
}

second_half_scores = {
    gw: score
    for gw, score in team_gw_scores.items()
    if gw >= 20
}


# Find weakest gameweek

worst_first_half = min(
    first_half_scores,
    key=first_half_scores.get
)

worst_second_half = min(
    second_half_scores,
    key=second_half_scores.get
)


print("Free hit recommendation:")

print(f"\nFirst Half")
print(f"Recommended Gameweek: {worst_first_half}")
print(f"Projected Team Points: {first_half_scores[worst_first_half]:.2f}")

print(f"\nSecond Half")
print(f"Recommended Gameweek: {worst_second_half}")
print(f"Projected Team Points: {second_half_scores[worst_second_half]:.2f}")
# Out:
# Free hit recommendation:
#
# First Half
# Recommended Gameweek: 12
# Projected Team Points: 242.82
#
# Second Half
# Recommended Gameweek: 35
# Projected Team Points: 238.16

# %%
squad_value = squad_df["selling_price"].sum()

free_hit_budget = squad_value + bank

print("Free hit budget:")
print(f"Squad Selling Value: £{squad_value:.1f}m")
print(f"Money In Bank: £{bank:.1f}m")
print(f"Available Budget: £{free_hit_budget:.1f}m")
# Out:
# Free hit budget:
# Squad Selling Value: £99.7m
# Money In Bank: £0.0m
# Available Budget: £99.7m

# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: pulp in ./.local/lib/python3.12/site-packages (3.3.2)

# %%
import pulp


# SELECT GAMEWEEK (we'll use worst first half as default)

target_gw = worst_first_half   # change to worst_second_half later


# Build player pool for that GW


gw_fixtures = [
    f for f in fixtures
    if f["event"] == target_gw and not f["finished"]
]

# Precompute player GW scores
player_gw_score = {}

for _, player in players_df.iterrows():

    team_id = player["team"]
    score = 0

    for fixture in gw_fixtures:

        if fixture["team_h"] == team_id:
            difficulty = fixture["team_h_difficulty"]

        elif fixture["team_a"] == team_id:
            difficulty = fixture["team_a_difficulty"]

        else:
            continue

        score += (
            player["projected_points"] *
            fixture_weights[difficulty]
        )

    player_gw_score[player["id"]] = score



#model

model = pulp.LpProblem("Free_Hit_Optimisation", pulp.LpMaximize)

players = players_df["id"].tolist()

# decision variables: 1 if player is selected
x = pulp.LpVariable.dicts("player", players, cat="Binary")


#objective

model += pulp.lpSum([
    player_gw_score.get(i, 0) * x[i]
    for i in players
])



#constraints


# Budget constraint
model += pulp.lpSum([
    players_df.loc[players_df["id"] == i, "price"].values[0] * x[i]
    for i in players
]) <= free_hit_budget


# Squad size = 15
model += pulp.lpSum([x[i] for i in players]) == 15


# Position constraints
model += pulp.lpSum([
    x[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 1
]) == 2  # GKs

model += pulp.lpSum([
    x[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 2
]) == 5  # DEF

model += pulp.lpSum([
    x[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 3
]) == 5  # MID

model += pulp.lpSum([
    x[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 4
]) == 3  # FWD


# Max 3 players per team
for team in players_df["team"].unique():

    model += pulp.lpSum([
        x[i]
        for i in players
        if players_df.loc[players_df["id"] == i, "team"].values[0] == team
    ]) <= 3



#solve

model.solve()

print("Status:", pulp.LpStatus[model.status])



#output squad

optimal_team = players_df[
    [x[i].value() == 1 for i in players]
].copy()

print("\nOPTIMAL FREE HIT TEAM:")
print(optimal_team[["name", "price", "position", "projected_points"]])
print("\nTotal projected score:",
      sum(player_gw_score.get(i, 0) for i in players if x[i].value() == 1))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eac2c248-9869-4f57-9431-017437213af6/.local/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/d32730129417430f9d7ad79f584e40b6-pulp.mps -max -timeMode elapsed -solve -printingOptions all -solution /tmp/d32730129417430f9d7ad79f584e40b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 4374 RHS
# At line 4401 BOUNDS
# At line 5054 ENDATA
# Problem MODEL has 26 rows, 652 columns and 2608 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 428.233 - 0.00 seconds
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 26 rows, 541 columns (541 integer (465 of which binary)) and 2164 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -428.233
# Cbc0038I Cleaned solution of -428.233
# Cbc0038I Before mini branch and bound, 541 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -428.233 - took 0.00 seconds
# Cbc0012I Integer solution of -428.23297 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -428.23297061861, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -428.233 to -428.233
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                428.23297062
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Status: Optimal
#
# OPTIMAL FREE HIT TEAM:
#             name  price  position  projected_points
# 0           Raya    6.0         1         19.715775
# 3        Gabriel    8.0         2         24.612092
# 75     Tavernier    6.0         3         28.851998
# 76         Scott    6.0         3         31.327502
# 123    De Cuyper    4.7         2         19.698252
# 132         Groß    5.5         3         27.379100
# 144    Kostoulas    5.5         4         18.700067
# 179   João Pedro    7.7         4         31.266947
# 229     Mitchell    4.5         2         19.541395
# 394        Bogle    4.5         2         19.617019
# 413     Trafford    5.0         1         14.919481
# 438        Gakpo    7.1         3         35.913293
# 450         Isak    9.0         4         39.195234
# 465     Gvardiol    5.6         2         29.942782
# 507  B.Fernandes   12.0         3         61.492217
#
# Total projected score: 428.2329706186105

# %%
#extracts optimal team


selected_ids = [i for i in players if x[i].value() == 1]

optimal_team = players_df[
    players_df["id"].isin(selected_ids)
].copy()


#team summary


total_optimal_points = sum(
    player_gw_score.get(i, 0)
    for i in selected_ids
)

current_team_points = sum(
    squad_gw_scores.get(i, 0)
    for i in squad_df["id"]
) if 'squad_gw_scores' in globals() else None


print("OPTIMAL FREE HIT TEAM:\n")

print(optimal_team[
    ["name", "position", "price", "projected_points"]
].sort_values("position"))



print(f"Total Optimal Projected Points: {total_optimal_points:.2f}")


#optimal comparison

if current_team_points is not None:
    print(f"Current Squad Projected Points: {current_team_points:.2f}")
    print(f"Expected Gain from Free Hit: {total_optimal_points - current_team_points:.2f}")
# Out:
# OPTIMAL FREE HIT TEAM:
#
#             name  position  price  projected_points
# 0           Raya         1    6.0         19.715775
# 413     Trafford         1    5.0         14.919481
# 123    De Cuyper         2    4.7         19.698252
# 3        Gabriel         2    8.0         24.612092
# 465     Gvardiol         2    5.6         29.942782
# 394        Bogle         2    4.5         19.617019
# 229     Mitchell         2    4.5         19.541395
# 75     Tavernier         3    6.0         28.851998
# 438        Gakpo         3    7.1         35.913293
# 507  B.Fernandes         3   12.0         61.492217
# 132         Groß         3    5.5         27.379100
# 76         Scott         3    6.0         31.327502
# 179   João Pedro         4    7.7         31.266947
# 144    Kostoulas         4    5.5         18.700067
# 450         Isak         4    9.0         39.195234
# Total Optimal Projected Points: 428.23

# %%
#free hit(second half of season)
#worst_second_half gw is best time to use free hit
target_gw = worst_second_half


#build gw fixtures


gw_fixtures = [
    f for f in fixtures
    if f["event"] == target_gw and not f["finished"]
]



#player gw scores

player_gw_score = {}

for _, player in players_df.iterrows():

    team_id = player["team"]
    score = 0

    for fixture in gw_fixtures:

        if fixture["team_h"] == team_id:
            difficulty = fixture["team_h_difficulty"]

        elif fixture["team_a"] == team_id:
            difficulty = fixture["team_a_difficulty"]

        else:
            continue

        score += (
            player["projected_points"] *
            fixture_weights[difficulty]
        )

    player_gw_score[player["id"]] = score



#solves model again


model2 = pulp.LpProblem("Free_Hit_Second_Half", pulp.LpMaximize)

players = players_df["id"].tolist()

x2 = pulp.LpVariable.dicts("player", players, cat="Binary")


#objective
model2 += pulp.lpSum([
    player_gw_score.get(i, 0) * x2[i]
    for i in players
])


# budget
model2 += pulp.lpSum([
    players_df.loc[players_df["id"] == i, "price"].values[0] * x2[i]
    for i in players
]) <= free_hit_budget


#squad size
model2 += pulp.lpSum([x2[i] for i in players]) == 15


#position constraints
model2 += pulp.lpSum([
    x2[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 1
]) == 2

model2 += pulp.lpSum([
    x2[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 2
]) == 5

model2 += pulp.lpSum([
    x2[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 3
]) == 5

model2 += pulp.lpSum([
    x2[i] for i in players
    if players_df.loc[players_df["id"] == i, "position"].values[0] == 4
]) == 3


# only allows a max of 3 per team
for team in players_df["team"].unique():

    model2 += pulp.lpSum([
        x2[i]
        for i in players
        if players_df.loc[players_df["id"] == i, "team"].values[0] == team
    ]) <= 3


#solve
model2.solve()

print("Status:", pulp.LpStatus[model2.status])


#output


selected_ids = [i for i in players if x2[i].value() == 1]

optimal_team_2 = players_df[
    players_df["id"].isin(selected_ids)
].copy()

total_points_2 = sum(
    player_gw_score.get(i, 0)
    for i in selected_ids
)

print("\nOptimal free hit team(second half):\n")

print(optimal_team_2[
    ["name", "position", "price", "projected_points"]
].sort_values("position"))

print("\nTotal projected score:", total_points_2)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eac2c248-9869-4f57-9431-017437213af6/.local/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/a1b7ce395607424ab11e06f860059bdc-pulp.mps -max -timeMode elapsed -solve -printingOptions all -solution /tmp/a1b7ce395607424ab11e06f860059bdc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 4374 RHS
# At line 4401 BOUNDS
# At line 5054 ENDATA
# Problem MODEL has 26 rows, 652 columns and 2608 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 438.93 - 0.00 seconds
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 26 rows, 541 columns (541 integer (465 of which binary)) and 2164 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.777778
# Cbc0038I Solution found of -437.957
# Cbc0038I Cleaned solution of -437.957
# Cbc0038I Before mini branch and bound, 539 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -438.054
# Cbc0038I Reduced cost fixing fixed 532 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.07778 (2) obj. -438.054 iterations 1
# Cbc0038I Pass   2: suminf.    0.91667 (2) obj. -438.868 iterations 4
# Cbc0038I Pass   3: suminf.    0.61388 (2) obj. -438.054 iterations 2
# Cbc0038I Pass   4: suminf.    0.61388 (2) obj. -438.054 iterations 0
# Cbc0038I Pass   5: suminf.    0.07778 (2) obj. -438.054 iterations 1
# Cbc0038I Pass   6: suminf.    0.91667 (2) obj. -438.868 iterations 3
# Cbc0038I Pass   7: suminf.    0.61388 (2) obj. -438.054 iterations 2
# Cbc0038I Pass   8: suminf.    0.61388 (2) obj. -438.054 iterations 0
# Cbc0038I Pass   9: suminf.    1.00000 (2) obj. -438.466 iterations 5
# Cbc0038I Pass  10: suminf.    0.46154 (2) obj. -438.611 iterations 1
# Cbc0038I Pass  11: suminf.    0.45777 (2) obj. -438.054 iterations 3
# Cbc0038I Pass  12: suminf.    0.66667 (2) obj. -438.827 iterations 4
# Cbc0038I Pass  13: suminf.    0.88789 (2) obj. -438.054 iterations 3
# Cbc0038I Pass  14: suminf.    0.88789 (2) obj. -438.054 iterations 0
# Cbc0038I Pass  15: suminf.    0.88789 (2) obj. -438.054 iterations 0
# Cbc0038I Pass  16: suminf.    0.61388 (2) obj. -438.054 iterations 3
# Cbc0038I Pass  17: suminf.    0.91667 (2) obj. -438.868 iterations 3
# Cbc0038I Pass  18: suminf.    0.61388 (2) obj. -438.054 iterations 3
# Cbc0038I Pass  19: suminf.    0.04142 (2) obj. -438.054 iterations 1
# Cbc0038I Pass  20: suminf.    0.04142 (2) obj. -438.054 iterations 0
# Cbc0038I Pass  21: suminf.    0.25000 (2) obj. -438.416 iterations 2
# Cbc0038I Pass  22: suminf.    0.04142 (2) obj. -438.054 iterations 2
# Cbc0038I Pass  23: suminf.    0.91667 (2) obj. -438.868 iterations 3
# Cbc0038I Pass  24: suminf.    0.66667 (2) obj. -438.827 iterations 2
# Cbc0038I Pass  25: suminf.    0.66667 (2) obj. -438.827 iterations 0
# Cbc0038I Pass  26: suminf.    0.88789 (2) obj. -438.054 iterations 3
# Cbc0038I Pass  27: suminf.    0.88789 (2) obj. -438.054 iterations 0
# Cbc0038I Pass  28: suminf.    0.04142 (2) obj. -438.054 iterations 1
# Cbc0038I Pass  29: suminf.    0.04142 (2) obj. -438.054 iterations 1
# Cbc0038I Pass  30: suminf.    0.25000 (2) obj. -438.416 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 535 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound improved solution from -437.957 to -437.983 (0.02 seconds)
# Cbc0038I Round again with cutoff of -438.229
# Cbc0038I Reduced cost fixing fixed 533 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.21778 (2) obj. -438.229 iterations 0
# Cbc0038I Pass  31: suminf.    0.91667 (2) obj. -438.868 iterations 3
# Cbc0038I Pass  32: suminf.    0.71483 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  33: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  34: suminf.    0.14238 (2) obj. -438.229 iterations 0
# Cbc0038I Pass  35: suminf.    0.25000 (2) obj. -438.416 iterations 2
# Cbc0038I Pass  36: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  37: suminf.    0.25000 (2) obj. -438.416 iterations 1
# Cbc0038I Pass  38: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  39: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  40: suminf.    0.25000 (2) obj. -438.416 iterations 2
# Cbc0038I Pass  41: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  42: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  43: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  44: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  45: suminf.    0.60000 (2) obj. -438.652 iterations 3
# Cbc0038I Pass  46: suminf.    0.46154 (2) obj. -438.611 iterations 1
# Cbc0038I Pass  47: suminf.    0.59777 (2) obj. -438.229 iterations 3
# Cbc0038I Pass  48: suminf.    0.66667 (2) obj. -438.827 iterations 3
# Cbc0038I Pass  49: suminf.    0.98884 (2) obj. -438.229 iterations 2
# Cbc0038I Pass  50: suminf.    0.14238 (2) obj. -438.229 iterations 1
# Cbc0038I Pass  51: suminf.    0.14238 (2) obj. -438.229 iterations 0
# Cbc0038I Pass  52: suminf.    0.25000 (2) obj. -438.416 iterations 1
# Cbc0038I Pass  53: suminf.    0.98884 (2) obj. -438.229 iterations 3
# Cbc0038I Pass  54: suminf.    0.66667 (2) obj. -438.827 iterations 1
# Cbc0038I Pass  55: suminf.    0.66667 (2) obj. -438.827 iterations 0
# Cbc0038I Pass  56: suminf.    0.66667 (2) obj. -438.827 iterations 1
# Cbc0038I Pass  57: suminf.    0.66667 (2) obj. -438.827 iterations 1
# Cbc0038I Pass  58: suminf.    0.66667 (2) obj. -438.827 iterations 0
# Cbc0038I Pass  59: suminf.    0.66667 (2) obj. -438.827 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 535 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -437.983 - took 0.02 seconds
# Cbc0012I Integer solution of -437.98251 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 26 rows 541 columns, reduced to 1 rows 2 columns
# Cbc0031I 1 added rows had average density of 2
# Cbc0013I At root node, 5 cuts changed objective from -438.92963 to -438.32991 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -437.98250778729, took 0 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 456 variables fixed on reduced cost
# Cuts at root node changed objective from -438.93 to -438.33
# Probing was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                437.98250779
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Status: Optimal
#
# Optimal free hit team(second half):
#
#              name  position  price  projected_points
# 0            Raya         1    6.0         19.715775
# 261      Pickford         1    5.5         18.448424
# 9           White         2    5.5         24.511295
# 7       Calafiori         2    5.7         23.645658
# 264     Tarkowski         2    6.0         24.182131
# 465      Gvardiol         2    5.6         29.942782
# 462         Guéhi         2    6.0         26.800902
# 97   Lewis-Potter         3    5.5         28.329775
# 507   B.Fernandes         3   12.0         61.492217
# 132          Groß         3    5.5         27.379100
# 298          King         3    5.5         26.871625
# 473        Cherki         3    7.8         36.709154
# 179    João Pedro         4    7.7         31.266947
# 450          Isak         4    9.0         39.195234
# 544         Wissa         4    6.1         20.959469
#
# Total projected score: 437.9825077872965

# %%
#wildcard player optimisations


# Use the first-half Wildcard by default.
# Change to wildcard_second for the second-half optimisation.
target_gw = wildcard_first

LOOKAHEAD = 6

future_points = {}

for _, player in players_df.iterrows():

    team = player["team"]
    total_projection = 0

    for fixture in fixtures:

        if fixture["finished"]:
            continue

        if fixture["event"] is None:
            continue

        # Only consider fixtures in the Wildcard window
        if not (target_gw <= fixture["event"] < target_gw + LOOKAHEAD):
            continue

        if fixture["team_h"] == team:
            difficulty = fixture["team_h_difficulty"]

        elif fixture["team_a"] == team:
            difficulty = fixture["team_a_difficulty"]

        else:
            continue

        # Adds every fixture, including doubles
        total_projection += (
            player["projected_points"]
            * fixture_weights[difficulty]
        )

    future_points[player["id"]] = total_projection



# add to dataframe


players_df["future_points"] = (
    players_df["id"]
    .map(future_points)
    .fillna(0)
)

players_df["future_value"] = (
    players_df["future_points"]
    / players_df["price"]
)

print("Long term play projections:")

print(
    players_df[
        [
            "name",
            "price",
            "future_points",
            "future_value"
        ]
    ]
    .sort_values("future_points", ascending=False)
    .head(20)
)
# Out:
# Long term play projections:
#              name  price  future_points  future_value
# 507   B.Fernandes   12.0     359.729471     29.977456
# 450          Isak    9.0     227.332356     25.259151
# 473        Cherki    7.8     216.584010     27.767181
# 438         Gakpo    7.1     208.297102     29.337620
# 76          Scott    6.0     197.363265     32.893878
# 179    João Pedro    7.7     193.855069     25.175983
# 567   Gibbs-White    7.9     189.197399     23.949038
# 75      Tavernier    6.0     181.767590     30.294598
# 465      Gvardiol    5.6     176.662416     31.546860
# 482       Haaland   15.5     169.137924     10.912124
# 471       Semenyo    8.5     168.421199     19.814259
# 97   Lewis-Potter    5.5     164.312695     29.875035
# 132          Groß    5.5     162.905646     29.619208
# 171        Palmer    9.6     160.584171     16.727518
# 298          King    5.5     158.542585     28.825925
# 462         Guéhi    6.0     158.125320     26.354220
# 117     M.Sangaré    5.7     155.347893     27.254016
# 156        Rogers    7.5     155.326954     20.710261
# 508        Mbeumo    7.9     151.694310     19.201811
# 3         Gabriel    8.0     150.133760     18.766720

# %%
import pulp


# wildcard optimisation model


model = pulp.LpProblem(
    "Wildcard_Optimisation",
    pulp.LpMaximize
)

players = players_df["id"].tolist()

# Binary decision variables
x = pulp.LpVariable.dicts(
    "player",
    players,
    cat="Binary"
)


# objective function

# Maximise projected points over
# the next LOOKAHEAD gameweeks

model += pulp.lpSum(
    players_df.loc[
        players_df["id"] == i,
        "future_points"
    ].values[0] * x[i]
    for i in players
)


# budget constraint


model += pulp.lpSum(
    players_df.loc[
        players_df["id"] == i,
        "price"
    ].values[0] * x[i]
    for i in players
) <= free_hit_budget



# squad size


model += pulp.lpSum(
    x[i]
    for i in players
) == 15



# position constraints


# Goalkeepers
model += pulp.lpSum(
    x[i]
    for i in players
    if players_df.loc[
        players_df["id"] == i,
        "position"
    ].values[0] == 1
) == 2


# Defenders
model += pulp.lpSum(
    x[i]
    for i in players
    if players_df.loc[
        players_df["id"] == i,
        "position"
    ].values[0] == 2
) == 5


# Midfielders
model += pulp.lpSum(
    x[i]
    for i in players
    if players_df.loc[
        players_df["id"] == i,
        "position"
    ].values[0] == 3
) == 5


# Forwards
model += pulp.lpSum(
    x[i]
    for i in players
    if players_df.loc[
        players_df["id"] == i,
        "position"
    ].values[0] == 4
) == 3



# ensures maximum 3 players per club


for team in players_df["team"].unique():

    model += pulp.lpSum(
        x[i]
        for i in players
        if players_df.loc[
            players_df["id"] == i,
            "team"
        ].values[0] == team
    ) <= 3


#solve

model.solve()

print("Status:", pulp.LpStatus[model.status])
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eac2c248-9869-4f57-9431-017437213af6/.local/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/3cd9e40b1d7e40ffa0f092f66c679637-pulp.mps -max -timeMode elapsed -solve -printingOptions all -solution /tmp/3cd9e40b1d7e40ffa0f092f66c679637-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 4374 RHS
# At line 4401 BOUNDS
# At line 5054 ENDATA
# Problem MODEL has 26 rows, 652 columns and 2608 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2680.69 - 0.00 seconds
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 26 rows, 541 columns (541 integer (465 of which binary)) and 2164 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.173913
# Cbc0038I Pass   1: suminf.    0.05333 (2) obj. -2675.64 iterations 5
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. -2325.5 iterations 1
# Cbc0038I Solution found of -2325.5
# Cbc0038I Cleaned solution of -2325.5
# Cbc0038I Before mini branch and bound, 537 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -2325.5 to -2632.96 (0.01 seconds)
# Cbc0038I Round again with cutoff of -2637.74
# Cbc0038I Reduced cost fixing fixed 442 variables on major pass 2
# Cbc0038I Pass   3: suminf.    0.20000 (2) obj. -2676.52 iterations 4
# Cbc0038I Pass   4: suminf.    0.64299 (2) obj. -2637.74 iterations 5
# Cbc0038I Pass   5: suminf.    0.26185 (2) obj. -2637.74 iterations 6
# Cbc0038I Pass   6: suminf.    0.26185 (2) obj. -2637.74 iterations 2
# Cbc0038I Pass   7: suminf.    0.35451 (3) obj. -2637.74 iterations 10
# Cbc0038I Pass   8: suminf.    0.46015 (2) obj. -2637.74 iterations 4
# Cbc0038I Pass   9: suminf.    0.97688 (3) obj. -2637.74 iterations 6
# Cbc0038I Pass  10: suminf.    0.36930 (2) obj. -2637.74 iterations 4
# Cbc0038I Pass  11: suminf.    0.60000 (2) obj. -2641.29 iterations 7
# Cbc0038I Pass  12: suminf.    0.64603 (2) obj. -2637.74 iterations 3
# Cbc0038I Pass  13: suminf.    0.60495 (4) obj. -2637.74 iterations 12
# Cbc0038I Pass  14: suminf.    0.10000 (2) obj. -2640.06 iterations 8
# Cbc0038I Pass  15: suminf.    0.13014 (2) obj. -2637.74 iterations 6
# Cbc0038I Pass  16: suminf.    1.02773 (4) obj. -2637.74 iterations 14
# Cbc0038I Pass  17: suminf.    0.35000 (2) obj. -2645.75 iterations 4
# Cbc0038I Pass  18: suminf.    0.45370 (2) obj. -2637.74 iterations 5
# Cbc0038I Pass  19: suminf.    0.69923 (3) obj. -2637.74 iterations 13
# Cbc0038I Pass  20: suminf.    0.26740 (2) obj. -2637.74 iterations 6
# Cbc0038I Pass  21: suminf.    0.80000 (2) obj. -2638.05 iterations 6
# Cbc0038I Pass  22: suminf.    0.78717 (3) obj. -2637.74 iterations 5
# Cbc0038I Pass  23: suminf.    0.36296 (3) obj. -2637.74 iterations 12
# Cbc0038I Pass  24: suminf.    0.36296 (3) obj. -2637.74 iterations 2
# Cbc0038I Pass  25: suminf.    0.22222 (2) obj. -2647.87 iterations 4
# Cbc0038I Pass  26: suminf.    0.10000 (2) obj. -2642.28 iterations 4
# Cbc0038I Pass  27: suminf.    0.15879 (2) obj. -2637.74 iterations 3
# Cbc0038I Pass  28: suminf.    1.31473 (4) obj. -2637.74 iterations 8
# Cbc0038I Pass  29: suminf.    0.21423 (2) obj. -2637.74 iterations 5
# Cbc0038I Pass  30: suminf.    0.30000 (2) obj. -2641.87 iterations 6
# Cbc0038I Pass  31: suminf.    0.95786 (2) obj. -2637.74 iterations 8
# Cbc0038I Solution found of -2637.74
# Cbc0038I Branch and bound needed to clear up 2 general integers
# Cbc0038I Full problem 27 rows 541 columns, reduced to 3 rows 4 columns
# Cbc0038I Cleaned solution of -2645.96
# Cbc0038I Rounding solution of -2659.62 is better than previous of -2645.96
#
# Cbc0038I Before mini branch and bound, 509 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 6 rows 16 columns
# Cbc0038I Mini branch and bound improved solution from -2659.62 to -2667.78 (0.03 seconds)
# Cbc0038I Round again with cutoff of -2670.36
# Cbc0038I Reduced cost fixing fixed 517 variables on major pass 3
# Cbc0038I Pass  32: suminf.    0.17391 (2) obj. -2680.19 iterations 6
# Cbc0038I Pass  33: suminf.    0.51250 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  34: suminf.    0.40000 (2) obj. -2678.93 iterations 8
# Cbc0038I Pass  35: suminf.    1.00569 (4) obj. -2670.36 iterations 6
# Cbc0038I Pass  36: suminf.    0.16806 (2) obj. -2670.36 iterations 3
# Cbc0038I Pass  37: suminf.    1.00000 (3) obj. -2670.36 iterations 7
# Cbc0038I Pass  38: suminf.    0.38325 (2) obj. -2670.36 iterations 3
# Cbc0038I Pass  39: suminf.    0.25527 (2) obj. -2670.36 iterations 3
# Cbc0038I Pass  40: suminf.    0.52174 (2) obj. -2673.06 iterations 4
# Cbc0038I Pass  41: suminf.    0.42872 (2) obj. -2670.36 iterations 3
# Cbc0038I Pass  42: suminf.    1.75186 (5) obj. -2670.36 iterations 5
# Cbc0038I Pass  43: suminf.    0.55556 (2) obj. -2670.54 iterations 5
# Cbc0038I Pass  44: suminf.    0.54470 (3) obj. -2670.36 iterations 4
# Cbc0038I Pass  45: suminf.    0.95523 (2) obj. -2670.36 iterations 5
# Cbc0038I Pass  46: suminf.    0.95523 (2) obj. -2670.36 iterations 0
# Cbc0038I Pass  47: suminf.    0.86957 (2) obj. -2672.43 iterations 5
# Cbc0038I Pass  48: suminf.    0.94090 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  49: suminf.    0.95523 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  50: suminf.    1.05224 (6) obj. -2670.36 iterations 9
# Cbc0038I Pass  51: suminf.    0.34783 (2) obj. -2673.14 iterations 4
# Cbc0038I Pass  52: suminf.    0.44365 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  53: suminf.    1.11330 (4) obj. -2670.36 iterations 5
# Cbc0038I Pass  54: suminf.    1.18907 (4) obj. -2670.36 iterations 3
# Cbc0038I Pass  55: suminf.    1.70874 (4) obj. -2670.36 iterations 4
# Cbc0038I Pass  56: suminf.    1.11371 (4) obj. -2670.36 iterations 1
# Cbc0038I Pass  57: suminf.    0.33118 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  58: suminf.    0.86957 (2) obj. -2672.43 iterations 5
# Cbc0038I Pass  59: suminf.    0.94090 (2) obj. -2670.36 iterations 4
# Cbc0038I Pass  60: suminf.    1.43129 (4) obj. -2670.36 iterations 6
# Cbc0038I Pass  61: suminf.    0.74603 (2) obj. -2670.36 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 522 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 7 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from -2667.78 to -2673.47 (0.04 seconds)
# Cbc0038I Round again with cutoff of -2675.64
# Cbc0038I Reduced cost fixing fixed 527 variables on major pass 4
# Cbc0038I Pass  61: suminf.    0.17391 (2) obj. -2680.57 iterations 1
# Cbc0038I Pass  62: suminf.    0.35763 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  63: suminf.    0.45708 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  64: suminf.    0.45708 (2) obj. -2675.64 iterations 1
# Cbc0038I Pass  65: suminf.    0.52174 (2) obj. -2676.29 iterations 4
# Cbc0038I Pass  66: suminf.    0.49752 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  67: suminf.    0.72820 (4) obj. -2675.64 iterations 1
# Cbc0038I Pass  68: suminf.    0.49752 (2) obj. -2675.64 iterations 1
# Cbc0038I Pass  69: suminf.    0.82307 (4) obj. -2675.64 iterations 3
# Cbc0038I Pass  70: suminf.    0.76367 (4) obj. -2675.64 iterations 1
# Cbc0038I Pass  71: suminf.    0.36726 (2) obj. -2675.64 iterations 2
# Cbc0038I Pass  72: suminf.    0.17391 (2) obj. -2680.57 iterations 4
# Cbc0038I Pass  73: suminf.    0.35763 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  74: suminf.    0.86781 (3) obj. -2675.64 iterations 6
# Cbc0038I Pass  75: suminf.    0.47721 (2) obj. -2675.64 iterations 6
# Cbc0038I Pass  76: suminf.    0.43478 (2) obj. -2676.77 iterations 3
# Cbc0038I Pass  77: suminf.    0.47721 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  78: suminf.    0.87423 (4) obj. -2675.64 iterations 3
# Cbc0038I Pass  79: suminf.    1.00000 (3) obj. -2675.64 iterations 3
# Cbc0038I Pass  80: suminf.    1.00000 (3) obj. -2675.64 iterations 0
# Cbc0038I Pass  81: suminf.    0.66667 (2) obj. -2678.2 iterations 3
# Cbc0038I Pass  82: suminf.    0.92082 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  83: suminf.    0.43478 (2) obj. -2679.26 iterations 3
# Cbc0038I Pass  84: suminf.    0.56966 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  85: suminf.    0.17391 (2) obj. -2680.57 iterations 4
# Cbc0038I Pass  86: suminf.    0.17391 (2) obj. -2680.57 iterations 2
# Cbc0038I Pass  87: suminf.    0.35763 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  88: suminf.    0.56966 (2) obj. -2675.64 iterations 3
# Cbc0038I Pass  89: suminf.    1.28481 (4) obj. -2675.64 iterations 2
# Cbc0038I Pass  90: suminf.    1.10509 (4) obj. -2675.64 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 531 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 541 columns, reduced to 2 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of -2673.47 - took 0.04 seconds
# Cbc0012I Integer solution of -2673.4698 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 26 rows 541 columns, reduced to 2 rows 4 columns
# Cbc0031I 5 added rows had average density of 6.2
# Cbc0013I At root node, 5 cuts changed objective from -2680.6886 to -2677.6012 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 3 row cuts average 5.7 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 12.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 6.5 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 8 row cuts average 7.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -2673.4698 best solution, best possible -2677.3179 (0.06 seconds)
# Cbc0001I Search completed - best objective -2673.469762555199, took 33 iterations and 2 nodes (0.07 seconds)
# Cbc0032I Strong branching done 22 times (62 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 0, 451 variables fixed on reduced cost
# Cuts at root node changed objective from -2680.69 to -2677.32
# Probing was tried 10 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 10 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 10 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 6 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2673.46976256
# Enumerated nodes:               2
# Total iterations:               33
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.08
#
# Status: Optimal

# %%
# extract optimal wildcard team

selected_ids = [
    i for i in players
    if x[i].value() == 1
]

wildcard_team = players_df[
    players_df["id"].isin(selected_ids)
].copy()

print("OPTIMAL WILDCARD SQUAD:\n")

print(
    wildcard_team[
        [
            "name",
            "position",
            "price",
            "future_points",
            "future_value"
        ]
    ]
    .sort_values(["position", "future_points"],
                 ascending=[True, False])
)



# transfers out


players_out = squad_df[
    ~squad_df["id"].isin(selected_ids)
]


print("PLAYERS TO SELL:")


print(
    players_out[
        [
            "name",
            "position",
            "selling_price",
            "projected_points"
        ]
    ]
    .sort_values("position")
)


# transfers in

players_in = wildcard_team[
    ~wildcard_team["id"].isin(user_squad_ids)
]

print("PLAYERS TO BUY:")


print(
    players_in[
        [
            "name",
            "position",
            "price",
            "future_points"
        ]
    ]
    .sort_values("position")
)
# Out:
# OPTIMAL WILDCARD SQUAD:
#
#              name  position  price  future_points  future_value
# 0            Raya         1    6.0     120.266228     20.044371
# 261      Pickford         1    5.5     114.380231     20.796406
# 465      Gvardiol         2    5.6     176.662416     31.546860
# 462         Guéhi         2    6.0     158.125320     26.354220
# 264     Tarkowski         2    6.0     149.929210     24.988202
# 9           White         2    5.5     149.518899     27.185254
# 229      Mitchell         2    4.5     119.202512     26.489447
# 507   B.Fernandes         3   12.0     359.729471     29.977456
# 473        Cherki         3    7.8     216.584010     27.767181
# 438         Gakpo         3    7.1     208.297102     29.337620
# 76          Scott         3    6.0     197.363265     32.893878
# 97   Lewis-Potter         3    5.5     164.312695     29.875035
# 450          Isak         4    9.0     227.332356     25.259151
# 179    João Pedro         4    7.7     193.855069     25.175983
# 281         Barry         4    5.5     117.910979     21.438360
# PLAYERS TO SELL:
#          name  position  selling_price  projected_points
# 14   Dubravka         1            4.0          5.338272
# 13   Horníček         1            5.0          9.768786
# 0        Cash         2            4.5          7.884346
# 2      Kayode         2            4.6         15.378022
# 6      Virgil         2            6.5         15.006033
# 5        Diop         2            4.0          5.585316
# 3      Thomas         2            4.0          9.513143
# 4      Slater         3            4.5          8.023873
# 12     Mbeumo         3            7.9         25.930651
# 7       Wirtz         3            7.4         20.239889
# 9     Semenyo         3            8.5         28.545966
# 1   N.Jackson         4            6.5          9.448188
# 11    Haaland         4           15.5         28.667445
# PLAYERS TO BUY:
#              name  position  price  future_points
# 0            Raya         1    6.0     120.266228
# 261      Pickford         1    5.5     114.380231
# 229      Mitchell         2    4.5     119.202512
# 9           White         2    5.5     149.518899
# 264     Tarkowski         2    6.0     149.929210
# 465      Gvardiol         2    5.6     176.662416
# 462         Guéhi         2    6.0     158.125320
# 76          Scott         3    6.0     197.363265
# 438         Gakpo         3    7.1     208.297102
# 97   Lewis-Potter         3    5.5     164.312695
# 507   B.Fernandes         3   12.0     359.729471
# 179    João Pedro         4    7.7     193.855069
# 281         Barry         4    5.5     117.910979

# %%
#wildcard summary
wildcard_budget = squad_value + bank

current_future_points = squad_df["projected_points"].sum()

wildcard_future_points = wildcard_team["future_points"].sum()

improvement = (
    wildcard_future_points -
    current_future_points
)

budget_used = wildcard_team["price"].sum()

remaining_budget = wildcard_budget - budget_used


print("WILDCARD SUMMARY:")

print(f"Recommended Wildcard GW: {target_gw}")

print(f"\nCurrent Squad Projection : {current_future_points:.2f}")
print(f"Wildcard Squad Projection: {wildcard_future_points:.2f}")
print(f"Expected Improvement     : +{improvement:.2f} points")

print(f"\nBudget Available : £{wildcard_budget:.1f}m")
print(f"Budget Used      : £{budget_used:.1f}m")
print(f"Money Remaining  : £{remaining_budget:.1f}m")

print(f"\nPlayers Sold : {len(players_out)}")
print(f"Players Bought: {len(players_in)}")


#best captain

captain = wildcard_team.loc[
    wildcard_team["future_points"].idxmax()
]

print("BEST CAPTAIN AFTER WILDCARD:")


print(f"Player: {captain['name']}")
print(f"Projected Points: {captain['future_points']:.2f}")


#best value signing

best_value = wildcard_team.loc[
    wildcard_team["future_value"].idxmax()
]

print("BEST VALUE SIGNING:")

print(f"Player: {best_value['name']}")
print(f"Price: £{best_value['price']:.1f}m")
print(f"Future Value Score: {best_value['future_value']:.2f}")


#top 5 signings

print("TOP 5 LONG-TERM SIGNINGS")


print(
    wildcard_team[
        [
            "name",
            "price",
            "future_points",
            "future_value"
        ]
    ]
    .sort_values(
        "future_points",
        ascending=False
    )
    .head(5)
)
# Out:
# WILDCARD SUMMARY:
# Recommended Wildcard GW: 19
#
# Current Squad Projection : 265.23
# Wildcard Squad Projection: 2673.47
# Expected Improvement     : +2408.24 points
#
# Budget Available : £99.7m
# Budget Used      : £99.7m
# Money Remaining  : £0.0m
#
# Players Sold : 13
# Players Bought: 13
# BEST CAPTAIN AFTER WILDCARD:
# Player: B.Fernandes
# Projected Points: 359.73
# BEST VALUE SIGNING:
# Player: Scott
# Price: £6.0m
# Future Value Score: 32.89
# TOP 5 LONG-TERM SIGNINGS
#             name  price  future_points  future_value
# 507  B.Fernandes   12.0     359.729471     29.977456
# 450         Isak    9.0     227.332356     25.259151
# 473       Cherki    7.8     216.584010     27.767181
# 438        Gakpo    7.1     208.297102     29.337620
# 76         Scott    6.0     197.363265     32.893878

# %%
#gaussian model

# Mean vector (expected points)

mu = wildcard_team["future_points"].values

# Estimate uncertainty
# (20% coefficient of variation)

sigma = 0.20 * mu

# Covariance matrix
# Assume players are independent for now

covariance = np.diag(sigma**2)

print("Mean Vector Shape:", mu.shape)
print("Covariance Matrix Shape:", covariance.shape)
# Out:
# Mean Vector Shape: (15,)
# Covariance Matrix Shape: (15, 15)

# %%
#monte carlo simulation

NUM_SIMULATIONS = 10000

samples = np.random.multivariate_normal(
    mean=mu,
    cov=covariance,
    size=NUM_SIMULATIONS
)

team_scores = samples.sum(axis=1)

print("Simulation Complete")
# Out:
# Simulation Complete

# %%
#results

mean_score = np.mean(team_scores)

std_score = np.std(team_scores)

lower95 = np.percentile(team_scores,2.5)

upper95 = np.percentile(team_scores,97.5)

print("Gaussian validation:\n")

print(f"Expected Score : {mean_score:.2f}")

print(f"Standard Deviation : {std_score:.2f}")

print(f"95% Confidence Interval")

print(f"{lower95:.2f}  ->  {upper95:.2f}")
# Out:
# Gaussian validation:
#
# Expected Score : 2672.01
# Standard Deviation : 145.35
# 95% Confidence Interval
# 2385.36  ->  2948.31

# %%
#probability of improvement

current_score = squad_df["projected_points"].sum()

probability = np.mean(team_scores > current_score)

print(f"Current Squad Projection : {current_score:.2f}")

print(f"Probability Wildcard Is Better : {probability*100:.2f}%")
# Out:
# Current Squad Projection : 265.23
# Probability Wildcard Is Better : 100.00%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.hist(team_scores, bins=50)

plt.axvline(
    current_score,
    linestyle="--",
    label="Current Squad"
)

plt.axvline(
    mean_score,
    linestyle="-",
    label="Wildcard Mean"
)

plt.xlabel("Projected Points")

plt.ylabel("Frequency")

plt.title("Monte Carlo Validation of Wildcard")

plt.legend()

plt.show()
